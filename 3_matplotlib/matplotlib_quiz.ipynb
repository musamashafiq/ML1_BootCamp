# %% [markdown]
# # **Name: Muhammad Usama Shafiq**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1: How do you create a basic line plot with Matplotlib?

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# %%
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ## Question 2: How do you create a histogram with Matplotlib?

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5, 6, 6, 7]
plt.hist(data, bins=7)
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Question 3: How do you create a pie chart with Matplotlib?

# %%
sizes = [15, 30, 45, 10]
labels = ['A', 'B', 'C', 'D']

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x18894410850>,
#   <matplotlib.patches.Wedge at 0x1889448ff50>,
#   <matplotlib.patches.Wedge at 0x18894b73090>,
#   <matplotlib.patches.Wedge at 0x18894550950>],
#  [Text(-1.0718071159153977, 0.24744596637067523, 'A'),
#   Text(-0.4120669678020202, -1.0199023551529083, 'B'),
#   Text(1.0125552161498554, 0.4298045302782647, 'C'),
#   Text(-0.5829112236950298, 0.9328528851273191, 'D')],
#  [Text(-0.5846220632265805, 0.13497052711127738, '15.0%'),
#   Text(-0.22476380061928372, -0.5563103755379499, '30.0%'),
#   Text(0.5523028451726483, 0.23443883469723525, '45.0%'),
#   Text(-0.31795157656092526, 0.5088288464330831, '10.0%')])

# %% [markdown]
# ## Question 4: How do you customize line styles and markers in Matplotlib?
#     ```linestyle='--', marker='o'```

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# %%
plt.plot(x, y, linestyle='--', marker='o')
plt.title('Customized Line Style and Marker')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# ## Question 5: How do you save a figure to a file in Matplotlib?

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# %%
plt.plot(x, y, linestyle='--', marker='o')
plt.title('Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.savefig('line_plot.png')

# %% [markdown]
# ## Question 6: How do you create a heatmap in Matplotlib?

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: pandas>=1.2 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\summer_bootcamp_ml1\practice\practice_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = np.random.rand(10, 10)

# %%
sns.heatmap(data, cmap='viridis')
plt.title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %% [markdown]
# ## Question 7: Create a plot with twin axes, one for each dataset.

# %%
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 25, 30, 35]
y2 = [1, 2, 3, 4, 5]

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, y1, 'g-')
ax1.set_xlabel('X Data')
ax1.set_ylabel('Y1 Axis', color='g')
ax1.tick_params(axis='y', labelcolor='g')

ax2 = ax1.twinx()
ax2.plot(x, y2, 'b-')
ax2.set_ylabel('Y2 Axis', color='b')
ax2.tick_params(axis='y', labelcolor='b')

plt.title('Twin Axes Plot')
# Out:
# Text(0.5, 1.0, 'Twin Axes Plot')

# %% [markdown]
# ## Question 8: Plot a confusion matrix.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

y_true = [2, 0, 2, 2, 0, 1]
y_pred = [0, 0, 2, 2, 0, 2]

# %%
cm = confusion_matrix(y_true, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['0', '1'], yticklabels=['True 0', 'True 1'])

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')

plt.show()

# %% [markdown]
# ## Question 9: Plot a Precision-Recall curve.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve
import numpy as np

y_true = np.array([0, 0, 1, 1])
y_scores = np.array([0.1, 0.4, 0.35, 0.8])

precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
plt.plot(recall, precision, marker='.')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')

# Display the plot
plt.show()
